# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("C:/Users/ACER/Downloads/turboaz.csv")
df
# Out:
#         Sheher     Marka  Model  Buraxilish ili Ban novu       Reng  \
# 0     Sumqayıt  Mercedes  C 200            1999    Sedan       Qara
# 1         Bakı  Mercedes  C 180            2014    Sedan       Qara
# 2     Sumqayıt  Mercedes  C 240            2002    Sedan       Qara
# 3       Şirvan  Mercedes  C 180            1998    Sedan        Göy
# 4     Sumqayıt  Mercedes  C 220            2000    Sedan     Gümüşü
# ...        ...       ...    ...             ...      ...        ...
# 1323      Bakı  Mercedes  C 180            1996    Sedan        Boz
# 1324  Sumqayıt  Mercedes  C 180            1994    Sedan  Bənövşəyi
# 1325      Bakı  Mercedes  C 230            1998    Sedan         Ağ
# 1326     Qusar  Mercedes  C 240            2000    Sedan     Gümüşü
# 1327      Bakı  Mercedes  C 220            1996    Sedan       Qara
#
#      Muherrikin hecmi Muherrikin gucu Yanacaq novu      Yurush  \
# 0               2.0 L        175 a.g.       Benzin  366 000 km
# ...

# %%
df1 = df[["Yurush","Buraxilish ili","Qiymet"]]
df1
# Out:
#           Yurush  Buraxilish ili     Qiymet
# 0     366 000 km            1999  12500 AZN
# 1     102 000 km            2014    31500 $
# 2     469 700 km            2002  11700 AZN
# 3     556 680 km            1998   9700 AZN
# 4     300 000 km            2000  12700 AZN
# ...          ...             ...        ...
# 1323  325 000 km            1996   8800 AZN
# 1324  280 000 km            1994   6300 AZN
# 1325  272 000 km            1998  10900 AZN
# 1326  207 000 km            2000  11300 AZN
# 1327  255 700 km            1996  10500 AZN
#
# [1328 rows x 3 columns]

# %%
df1.isnull().sum()
# Out:
# Yurush            0
# Buraxilish ili    0
# Qiymet            0
# dtype: int64

# %%
df1.shape
# Out:
# (1328, 3)

# %%
df1['Qiymet'] = df['Qiymet'].str.replace(r'\D', '').astype(int)
df1['Yurush'] = df['Yurush'].str.replace(r'\D', '').astype(int)
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13456/3920768654.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Qiymet'] = df['Qiymet'].str.replace(r'\D', '').astype(int)
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13456/3920768654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Qiymet'] = df['Qiymet'].str.replace(r'\D', '').astype(int)
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13456/3920768654.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Yurush'] = df['Yurush'].str.replace(r'\D', '').astype(int)
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13456/3920768654.py:2: SettingWithCopyWarning:
# ...

# %%
df1
# Out:
#       Yurush  Buraxilish ili  Qiymet
# 0     366000            1999   12500
# 1     102000            2014   31500
# 2     469700            2002   11700
# 3     556680            1998    9700
# 4     300000            2000   12700
# ...      ...             ...     ...
# 1323  325000            1996    8800
# 1324  280000            1994    6300
# 1325  272000            1998   10900
# 1326  207000            2000   11300
# 1327  255700            1996   10500
#
# [1328 rows x 3 columns]

# %%
df1
# Out:
#       Yurush  Buraxilish ili  Qiymet
# 0     366000            1999   12500
# 1     102000            2014   31500
# 2     469700            2002   11700
# 3     556680            1998    9700
# 4     300000            2000   12700
# ...      ...             ...     ...
# 1323  325000            1996    8800
# 1324  280000            1994    6300
# 1325  272000            1998   10900
# 1326  207000            2000   11300
# 1327  255700            1996   10500
#
# [1328 rows x 3 columns]

# %%
ones_col = np.ones(len(df1))
ones_col
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
df1["ones"] = ones_col.tolist()
df1
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13456/3450286716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["ones"] = ones_col.tolist()
#       Yurush  Buraxilish ili  Qiymet  ones
# 0     366000            1999   12500   1.0
# 1     102000            2014   31500   1.0
# 2     469700            2002   11700   1.0
# 3     556680            1998    9700   1.0
# 4     300000            2000   12700   1.0
# ...      ...             ...     ...   ...
# 1323  325000            1996    8800   1.0
# 1324  280000            1994    6300   1.0
# 1325  272000            1998   10900   1.0
# 1326  207000            2000   11300   1.0
# 1327  255700            1996   10500   1.0
#
# [1328 rows x 4 columns]

# %%
df1 = df1.loc[:, ["ones","Yurush","Buraxilish ili","Qiymet"]]
df1
# Out:
#       ones  Yurush  Buraxilish ili  Qiymet
# 0      1.0  366000            1999   12500
# 1      1.0  102000            2014   31500
# 2      1.0  469700            2002   11700
# 3      1.0  556680            1998    9700
# 4      1.0  300000            2000   12700
# ...    ...     ...             ...     ...
# 1323   1.0  325000            1996    8800
# 1324   1.0  280000            1994    6300
# 1325   1.0  272000            1998   10900
# 1326   1.0  207000            2000   11300
# 1327   1.0  255700            1996   10500
#
# [1328 rows x 4 columns]

# %%
def compute_cost(X, y, w):
    n=len(y)
    J = np.sum((X.dot(w)-y)**2)/(2*n)
    return J
compute_cost(df1.iloc[:,:3].values,df1.iloc[:,-1].values,[0,3,1])
# Out:
# 409619257182.8155

# %%
X = (x-x.mean())/x.std()
X
# Out:
# array([[-0.63150447,  1.83040024, -0.61806486],
#        [-0.63150447,  0.05459527, -0.61796396],
#        [-0.63150447,  2.52794181, -0.61804468],
#        ...,
#        [-0.63150447,  1.19810604, -0.61807158],
#        [-0.63150447,  0.76088134, -0.61805813],
#        [-0.63150447,  1.08846354, -0.61808504]])

# %%
def grad_descent(X,y,w,alpha,iterations):
    cost_history = [0]*iterations
    n = len(y)
    for iteration in range(iterations):
        if iteration%10000==0:
            print(f"Iteration {iteration} Cost {compute_cost(x, y, w)}")
        h = X.dot(w)
        loss = h-y
        gradient = X.T.dot(loss) / n
        w = w - alpha*gradient
        
        cost = compute_cost(X, y, w)
        cost_history[iteration]=cost
    return w,cost_history
grad_descent(df1.iloc[:,:3].values,df1.iloc[:,-1].values,np.zeros(3),0.001,10000)
# Out:
# Iteration 0 Cost 113160087.18524097
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13456/4194780877.py:3: RuntimeWarning: overflow encountered in square
#   J = np.sum((X.dot(w)-y)**2)/(2*n)
# (array([nan, nan, nan]),
#  [4.637096048965407e+23,
#   3.9887106680173817e+39,
#   3.430986252108555e+55,
#   2.9512460646861377e+71,
#   2.5385859033893435e+87,
#   2.1836262540082197e+103,
#   1.8782990998365594e+119,
#   1.615664540564522e+135,
#   1.3897530525701198e+151,
#   1.19542980528193e+167,
#   1.0282779496066552e+183,
#   8.844982256385212e+198,
#   7.608226077948637e+214,
#   6.544400245844514e+230,
#   5.629324646640556e+246,
#   4.8422001691287956e+262,
#   4.165135953191738e+278,
#   3.582742741445112e+294,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   inf,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(compute_cost(df1.iloc[:,:3].values,df1.iloc[:,-1].values,[0,3,1]))
